# %% [markdown]
# # ***Python_basics Assignment***

# %% [markdown]
# ## 1st_Question

# %%
month_number = int(input("Month Number: "))

if month_number == 1:
    print("Days in Month: 31")
elif month_number == 2:
    print("Days in Month: 28 or 29")
elif month_number == 3:
    print("Days in Month: 31")
elif month_number == 4:
    print("Days in Month: 30")
elif month_number == 5:
    print("Days in Month: 31")
elif month_number == 6:
    print("Days in Month: 30")
elif month_number == 7:
    print("Days in Month: 31")
elif month_number == 8:
    print("Days in Month: 31")
elif month_number == 9:
    print("Days in Month: 30")
elif month_number == 10:
    print("Days in Month: 31")
elif month_number == 11:
    print("Days in Month: 30")
elif month_number == 12:
    print("Days in Month: 31")
else:
    print("Invalid month number")
# Out:
# Month Number:  12
# Days in Month: 31

# %% [markdown]
# ## 2nd_Question

# %%
year = int(input("Enter a year: "))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print(year, "is a leap year")
        else:
            print(year, "is not a leap year")
    else:
        print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# Enter a year:  1853
# 1853 is not a leap year

# %% [markdown]
# ## 3rd_Question

# %%
class BankAccount:
    def __init__(self, accountName, accountNumber):
        self.accountName = accountName
        self.accountNumber = accountNumber
        self.balance = 0

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient balance")

    def get_balance(self):
        return self.balance

# %%
account = BankAccount("Samir Kostandy", "5542")
print(account.get_balance())  
account.deposit(3000)
print(account.get_balance())  
account.withdraw(200)
print(account.get_balance())  
account.withdraw(2900)
# Out:
# 0
# 3000
# 2800
# Insufficient balance

# %% [markdown]
# ## 4th_Question

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        pass
class Dog(Animal):
    def speak(self):
        return "Woof!"
class Cat(Animal):
    def speak(self):
        return "Meow!"
class Bird(Animal):
    def speak(self):
        return "Chirp!"
dog = Dog("Buddy")
cat = Cat("Whiskers")
bird = Bird("Tweety")
print(dog.name + ": " + dog.speak())  
print(cat.name + ": " + cat.speak())  
print(bird.name + ": " + bird.speak())
# Out:
# Buddy: Woof!
# Whiskers: Meow!
# Tweety: Chirp!

# %% [markdown]
# ## 5th_Question

# %%
import re

text = '''
Aljazeera's brave veteran journalist Wael Dahdouh's wife,
son and daughter were killed in an Israeli airstrike which targeted a shelter house they had fled to.
Wael received the news while on air covering the nonstop Israeli strikes on Gaza!
'''
clean_text = re.sub(r'[^\w\s]', '', text.lower())

#Tokenize the text into individual words
tokens = nltk.word_tokenize(clean_text)
#Perform part-of-speech tagging
pos_tags = nltk.pos_tag(tokens)


#Filter the tagged words to keep only nouns, verbs, adjectives, and adverbs
nouns = [word for word, pos in pos_tags if pos.startswith('NN')]
verbs = [word for word, pos in pos_tags if pos.startswith('VB')]
adjectives = [word for word, pos in pos_tags if pos.startswith('JJ')]
adverbs = [word for word, pos in pos_tags if pos.startswith('RB')]

#Count the frequency of each word
word_frequency = {}
for word in tokens:
    if word in word_frequency:
        word_frequency[word] += 1
    else:
        word_frequency[word] = 1

#Print the identified words for each part of speech
print("Nouns:", nouns)
print("Verbs:", verbs)
print("Adjectives:", adjectives)
print("Adverbs:", adverbs)

#Print the word frequency
for word, frequency in word_frequency.items():
    print(f"{word}:{frequency}", end=" ")
# Out:
# Nouns: ['aljazeeras', 'journalist', 'wael', 'wife', 'son', 'daughter', 'airstrike', 'shelter', 'house', 'news', 'air', 'strikes', 'gaza']
# Verbs: ['brave', 'were', 'killed', 'targeted', 'had', 'fled', 'wael', 'received', 'covering']
# Adjectives: ['veteran', 'dahdouhs', 'israeli', 'nonstop', 'israeli']
# Adverbs: []
# aljazeeras:1 brave:1 veteran:1 journalist:1 wael:2 dahdouhs:1 wife:1 son:1 and:1 daughter:1 were:1 killed:1 in:1 an:1 israeli:2 airstrike:1 which:1 targeted:1 a:1 shelter:1 house:1 they:1 had:1 fled:1 to:1 received:1 the:2 news:1 while:1 on:2 air:1 covering:1 nonstop:1 strikes:1 gaza:1

# %% [markdown]
# ## Name and Id

# %% [markdown]
# ### Name: ***Abdelrhman Mohamed Abdelhady Hodib ID : 2022513643***
