# %% [markdown]
# | Name | ID | Department |
# | --- | --- | --- |
# |Abdelrhman Mohamed Abdelhady Hodib| 2022513643 | Intelligent system|

# %% [markdown]
# <font size=5> __Comparing the model after tweakining__

# %% [markdown]
# __1st applied tweaks was in the vocab_size and maxlength__
#
# >vocab_size from 1000 to 500
#
# >> If you decrease the vocab_size as he did,it will limit the vocabulary and lose some important words,which could reduce model performance.
#
# >max_length from 100 to 50
#
# >>If you set max_length to be too short, you may truncate or lose important information from longer texts, which could reduce performance

# %% [markdown]
# __2nd applied tweaks was in changing Flatten() to GlobalAveragePooling1D__
# > We can't decide which one is better as Flatten is better than GlobalAveragePooling1D in some situations and vice versa.

# %% [markdown]
# __3rd applied tweaks was in Num_epochs from 10 to 30__
#
# > We opserved that the lose decreases and the model accuracy increased

# %% [markdown]
# __The observation of the results on predicating the sentiments of the new reviews of the same sentences__

# %% [markdown]
# >It appears that the first model in colab 13 performs better compared to the second model in colab 15 for that reasons:
#
# >>the sentiment scores (ranging from 0 to 1) for the majority of the examples are consistently higher in the first model compared to the second model
#
# >>The sentiment scores from the first model are more aligned with the sentiment expressed in the text samples. For example, in the first model, "I love this phone" has a sentiment score of 0.96667373, indicating a highly positive sentiment,In contrast, the second model has higher sentiment scores for some of the negative examples ("Everything was cold").

# %% [markdown]
# <font size=5>__Visualizing the results using the "Embedding Projector" tool__

# %% [markdown]
# <font size=3>__Positive words__

# %% [markdown]
# ![goodWords.jpg](attachment:goodWords.jpg)

# %% [markdown]
# __After we used PCA with vecs and meta of our model we observed visually that the positive words are nearest to each other and when we see the nighbours of the word fantastic we found positive words like amazing ,loved ,best are the nearest to it .__

# %% [markdown]
# <font size=3>__Negative words__

# %% [markdown]
# ![badwords.jpg](attachment:badwords.jpg)

# %% [markdown]
# __After we used PCA with vecs and meta of our model we observed visually that the negative words are nearest to each other and when we see the nighbours of the word like bad we found negative words like poor , worst and not are the nearest to it .__

# %% [markdown]
# <font size=5>__The last question in the colab notebook__

# %% [markdown]
# ![conclusion%20of%20the%20last%20question.jpg](attachment:conclusion%20of%20the%20last%20question.jpg)

# %% [markdown]
# __When we add the negative word "not" to the sentence we found that the sentiment score had been reduced , Generally the presence of negation words like "not" can have a significant impact on the sentiment analysis results__
